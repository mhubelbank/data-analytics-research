# %% [markdown]
# <center> <h1>ADVANCE Network Log Task</h1> </center>
# <center> <h3>Measuring Individuals' Positional Power in the Academic Heirarchy</h3> </center>
# <center> <h4>Mara Hubelbank, Dec. 2020 - March 2021</h4> </center>
#
#
# 03.03.2021: Running on new, cleaned data (Nelson)

# %% [markdown]
# ---
# ---
#
# ## Executive Summary
#
# The goal of this task is to provide a measure for individuals’ status within the hierarchical structure of academia. Specifically, we wish to determine the positions of academic individuals at different points after they've entered the ADVANCE network, focusing mainly on the categories of these jobs for a consistent measure of institutional power.
#
# To accomplish this, we determine three pieces of data for each individual in the network:
# - Their first job was when they first joined the ADVANCE network (were involved in their first ADVANCE grant)
# - Their highest job, in the hierarchy of the university/academic world (after the time they joined the network)
# - Their most-recently held job
#
# We also find these jobs at the role-level, e.g. we look for the best guess for the first job each award member had at the time of the given grant, etc.
#
# This report also analyzes our current records of ADVANCE network individuals' jobs and award roles, cleaning and processing the dataset programmatically wherever possible. Since some errors are not generalizable, we generate a readable report of issues which must be looked at and resolved manually.
#
# ### Task Subsections:
#
# **[1. Dataset Rundown](#one)**: Generate an overview of current dataset attributes, define relevant terms/data, determine column-wise frequencies of missing data, and visualize terminology trends in the dataset via NLP.
#
# **[2. Data Cleaning & Pre-Processing](#two)**: Space-trim the dataset, clean the individual jobs file for processing, and label each organization as a university or non-university.
#
# **[3. Error Detection](#three)**: Detect university-labeled posititions in non-universities, systematically question our recorded job and award years, and predict errors in job category placement based on job title terminology.
#
# **[4. Location of First, Highest, and Last Positions](#four)**: Given the cleaned dataset, we find first, highest, and latest positions at the person level and at the role level, and visualize the distribution of job categories between the individuals. The person level is 95% filled, and we output a set of 74 individuals (5% of overall) whose records necessitate further research. This algorithm accounts for all edge cases, including individuals whose first year in the ADVANCE network involved more than one grant.
#
# ### NOTE:
#
# The cells in this task are cumulative processes, so they must be run in order (should use Run-All).

# %% [markdown]
# ----
# ----
#
# ### Input/Output
#
# The input files needed for this task are:
# - Individual jobs
# - Individual awards
# - Individual demographics
# - Organizations
#
# The output files from this task are:
# - A txt file with seven sections for manual review
# - A csv file with the logged first, highest, and last positions at the individual level
# - A csv file with the logged first, highest, and last positions at the role level
# - Three csv files: demographics, jobs, and award data for the individuals missing first/highest/last job info
# - Three csv files: demographics, jobs, demographics, and award data for the individuals with at least one student position
# - Three csv files: demographics, jobs, and award data for the individuals with at least one NaN-category position
# - A png multi-pie graph visualizing the first, highest, and last positions at the individual level
# - A png multi-bar graph visualizing the job title term frequencies across the job categories
# - A png multi-bar graph visualizing the award role title term frequencies across the award role categories

# %%
import pandas as pd
import numpy as np
import math
import functools
from datetime import datetime
from pytz import timezone

# NLP
import re 
import nltk
from nltk.corpus import stopwords
# nltk.download('stopwords')
from collections import Counter

# Viz
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.lines import Line2D

# INPUT/OUTPUT PATHS ---------------------------------------------------------------------------
inp_ipynb = 'Input/'
out_ipynb = 'Output/'
inp_py = '../../ADVANCE/data_master/'

awards = pd.read_csv(inp_ipynb + 'awards_02.csv')
ind_awards = pd.read_csv(inp_ipynb + 'individual_awards.csv')
ind_dems = pd.read_csv(inp_ipynb + 'individual_demographics_02.csv')
ind_jobs = pd.read_csv(inp_ipynb + 'individual_jobs_02.csv')
orgs = pd.read_csv(inp_ipynb + 'organizations.csv')

# DATAFRAMES ------------------------------------------------------------------------------------
# Master dataframes, person and role level -- we log the first, highest, and last positions
log_individual_jobs = ind_dems[['person_id', 'name']].copy()
log_individual_awards = ind_awards[['person_id', 'name', 'award_id', 'award_start_year',
                                    'award_org_name', 'award_org_id', 'award_role_cat', 'award_role']
                                  ].copy()

ind_awards = ind_awards.drop_duplicates(['person_id', 'award_id'])

# We log the jobs, demographics, and award data for the individuals missing first/highest/last job info
log_missing_dems = pd.DataFrame()
log_missing_jobs = pd.DataFrame()
log_missing_awards = pd.DataFrame()

# We log the jobs, demographics, and award data for the individuals with student jobs
list_student = []
log_student_dems = pd.DataFrame()
log_student_jobs = pd.DataFrame()
log_student_awards = pd.DataFrame()

# We log the jobs, demographics, and award data for the individuals with NaN-category jobs
list_nan = []
log_nan_dems = pd.DataFrame()
log_nan_jobs = pd.DataFrame()
log_nan_awards = pd.DataFrame()

# %%
# We write our report to the log_task_report.txt file, which is generated in this file's source root folder.

N = 120
LINE = '-' * N

# Enforce a max line length of N
# Split the given sequence into a list of max-n-character chunks
def split_str(seq):
    lst = []
    if N <= len(seq):
        lst.extend([seq[:N]])
        lst.extend(split_str(seq[N:]))
    elif seq:
        lst.extend([seq])
    return lst

# Add the given string as a line to the report, and print it to the console
def out(out, print_to_con=True):
    f = open(out_ipynb + "log_task_report.txt", "a")
    [f.write(line + '\n') for line in split_str(out)]
    if print_to_con:
        print(out)

# Output a new section header to the report
def section(num, name):
    out('\n', False)
    out(LINE, False)
    out('Section ' + str(num) + ': ' + name, False)
    out(LINE, False)
    
# Reset the report, adding the header
def clear():
    open(out_ipynb + 'log_task_report.txt', 'w').close()
    now = datetime.now(timezone('EST'))
    dt_string = now.strftime("%m/%d/%Y %H:%M:%S EST")
    out(LINE, False)
    out('ADVANCE Network Log Task Report\nGenerated ' + dt_string + ' by Mara Hubelbank', False)
    out(LINE, False)
    
# Print the current state of the report to console
def read():
    f = open(out_ipynb + "log_task_report.txt", "r")
    print(f.read())

# %%
# Helper functions and data structures to be used throughout   

# Get the grantees that worked on a given award
def get_grantees(award_id):
    return ind_awards[ind_awards['award_id'] == award_id]

# Get the demographics row for the given person
def get_dems(person_id):
    return ind_dems[ind_dems['person_id'] == person_id]

# Get the jobs for the given person
def get_jobs(person_id, first_year=None):
    ind_jobs_copy = ind_jobs.copy() # make a copy, prior to cleaning
    return ind_jobs_copy[ind_jobs_copy['person_id'] == person_id].sort_values('job_start_year')

# Get the awards for the given person
def get_awards(person_id):
    return ind_awards[ind_awards['person_id'] == person_id].sort_values('award_start_year')

job_cats = ind_jobs['job_category'].unique()
job_cats = [x for x in job_cats if str(x) != 'nan']

role_cats = ind_awards['award_role_cat'].unique()
role_cats = [x for x in role_cats if str(x) != 'nan']

# %% [markdown]
# ---
# ---
#
# <a id='one'></a>
#
# # 1. Dataset Rundown
#
# This section generates an overview of current dataset attributes, defines relevant terms/data, determines column-wise frequencies of missing data, and visualizes terminology trends in the dataset via NLP.

# %% [markdown]
# ## 1.1 Overview

# %%
clear()
section(1, 'Dataset Rundown')

out('\nOur current dataset includes:')
out(str(len(orgs)) + ' organizations')
out(str(len(awards)) + ' awards')
out(str(len(ind_dems)) + ' individuals')
out(str(len(log_individual_awards)) + ' individual award roles (with some individuals having multiple roles per grant)')
out(str(len(ind_awards)) + ' individual award roles (after removal of duplicate individuals within the same grant)')
out(str(len(ind_jobs)) + ' individual jobs')

out('\nBetween these, there are:')
org_un = len(awards['awarded_org_id'].unique())
out(str(org_un) + ' grant-receiving organizations')

ind_un = len(log_individual_awards['person_id'].unique())
out(str(ind_un) + ' individuals with at least one award role')

avg_roles = len(log_individual_awards)/len(ind_dems)
out(f'{avg_roles:.2g}' + ' award roles per individual, on average')

out(str(len(role_cats)) + ' award role categories')

role_titles = len(log_individual_awards['award_role'].unique())
out(str(role_titles) + ' unique award role titles (before processing)')

out(str(len(job_cats)) + ' job categories')

job_titles = len(ind_jobs['job_title'].unique())
out(str(job_titles) + ' unique job titles (before processing)')
# Out:
# Our current dataset includes:
# 1360 organizations
# 273 awards
# 1590 individuals
# 2170 individual award roles (with some individuals having multiple roles per grant)
# 2024 individual award roles (after removal of duplicate individuals within the same grant)
# 6687 individual jobs
#
# Between these, there are:
# 195 grant-receiving organizations
# 1590 individuals with at least one award role
# 1.4 award roles per individual, on average
# 7 award role categories
# 112 unique award role titles (before processing)
# 13 job categories
# 2677 unique job titles (before processing)

# %% [markdown]
# ## 1.2 Definitions

# %% [markdown]
# ### Ordering of Job Categories
#
# *In descending order of power:*
#
# 1. admin_leadership (dean, provost, president)
# 2. director_managerial
# 3. chair_dept
# 4. director_research
# 5. director_chair
# 6. director_diversity
# 7. faculty (standard professor category)
# 8. staff_management (management staff - not higher admin or researchers)
# 9. staff_research (faculty researcher, those active in research)
# 10. adjunct (adjunct, visiting professor/scholar/scientist, instructor, lecturer - ALL visiting goes here)
# 11. postdoc
# 12. non-uni
# 13. deceased
#
#
# These job categories will not be considered in individual jobs processing:
# -  student
# -  NaN

# %%
# A dictionary representing precedence of job titles
job_dict = {"admin_leadership": 1, 
            "director_managerial": 2,
            "chair_dept": 3,
            "director_research": 4,
            "director_chair": 5,
            "director_diversity": 6, 
            "faculty": 7, 
            "staff_management": 8,
            "staff_research": 9,
            "adjunct": 10,
            "postdoc": 11, 
            "non-uni": 12,
            "deceased": 13
            } 

# A comparator for job titles, using the above dictionary
# Return: -1 if job1 < job2, 0 if =, 1 if job1 > job2
def job_comparator(job1, job2):
    if job_dict[job1] < job_dict[job2]:
        return -1
    elif job_dict[job1] > job_dict[job2]:
        return 1
    else:
        return 0

# Sort the given list using our custom precedence dictionary and job_comparator
def sort_jobs(job_list):
    job_list.sort(key=functools.cmp_to_key(job_comparator))

# Sort global variable
sort_jobs(job_cats)

# Given a list of job titles, sort by custom precedence list and return the highest job title
def get_highest_title(job_list):
    sort_jobs(job_list)
    
    # Sorted in descending order -- return first
    if (len(job_list) > 0):
        return job_list[0] 
    else:
        return None

# %%
out(' ', False)
out(LINE, False)
out('\nAmong the individual jobs,')
for cat in job_cats:
    count = len(ind_jobs[ind_jobs['job_category']==cat])
    perc = 100*count/len(ind_jobs)
    out(str(count) + ' are ' + cat + f' positions ({perc:.2g}%)')
# Out:
# Among the individual jobs,
# 1679 are admin_leadership positions (25%)
# 221 are director_managerial positions (3.3%)
# 416 are chair_dept positions (6.2%)
# 308 are director_research positions (4.6%)
# 244 are director_chair positions (3.6%)
# 140 are director_diversity positions (2.1%)
# 2276 are faculty positions (34%)
# 163 are staff_management positions (2.4%)
# 217 are staff_research positions (3.2%)
# 229 are adjunct positions (3.4%)
# 37 are postdoc positions (0.55%)
# 730 are non-uni positions (11%)
# 24 are deceased positions (0.36%)

# %% [markdown]
# ### Ordering of Award Role Categories
#
# *In descending order of power:*
#
# 1. grantee
# 2. day-to-day
# 3. researcher
# 4. internal evaluator
# 5. external advisor
# 6. external evaluator
# 7. external consultant

# %%
# A dictionary representing precedence of award roles
role_dict = {"grantee": 1, "day-to-day": 2, "researcher": 3, "internal evaluator": 4, "external advisor": 5, "external evaluator": 6, "external consultant": 7} 

# A comparator for award role categories using the above dictionary
# Return: -1 if role1 < role2, 0 if =, 1 if role1 > role2
def role_comparator(role1, role2):
    if role_dict[role1] < role_dict[role2]:
        return -1
    elif role_dict[role1] > role_dict[role2]:
        return 1
    else:
        return 0

# Sort the given list using our custom precedence dictionary and role_comparator
def sort_roles(role_list):
    role_list.sort(key=functools.cmp_to_key(role_comparator))

# Sort global variable
sort_roles(role_cats)

# Given a list of award roles, sort by custom precedence list and return the highest award role
def get_highest_role(role_list):
    sort_roles(role_list)
    
    # Sorted in descending order -- return first
    if (len(role_list) > 0):
        return role_list[0] 
    else:
        return None

# %%
out(' ', False)
out(LINE, False)
out('\nAmong the individual awards,')
for cat in role_cats:
    count = len(ind_awards[ind_awards['award_role_cat']==cat])
    perc = 100*count/len(ind_awards)
    out(str(count) + ' are ' + cat + f' roles ({perc:.2g}%)')
# Out:
# Among the individual awards,
# 1079 are grantee roles (53%)
# 121 are day-to-day roles (6%)
# 92 are researcher roles (4.5%)
# 105 are internal evaluator roles (5.2%)
# 455 are external advisor roles (22%)
# 124 are external evaluator roles (6.1%)
# 48 are external consultant roles (2.4%)

# %% [markdown]
# ## 1.3 Missing Data
#
# We define a cell as missing data if:
# - It is empty
# - It starts with "can't find" or "missing"

# %%
def analyze(df, name): 
    n = len(df)
    out('\nFILE: ' + name + ' (n=' + str(n) + ')')
    tups = []
    
    for col in df:
        na = df[col].isna().sum() + len(df[(df[col].astype(str).str.startswith('can\'t find'))
                                           | (df[col].astype(str).str.startswith('missing'))])
        tups.append((col, na))
      
    # Sort in descending order (most missing -> least missing)
    tups = sorted(tups, key=lambda x: x[1], reverse=True)
    for tup in tups:
        col = tup[0]
        na = tup[1]
        perc = 100*na/n
        out(col + ' column: ' + str(na) + f' rows missing ({perc:.2g}%)')

# %%
out('', False)
section(2, 'Missing Data')
analyze(ind_jobs, 'Individual Jobs')
# Out:
# FILE: Individual Jobs (n=6687)
# department column: 6609 rows missing (99%)
# job_end_year column: 1962 rows missing (29%)
# job_start_year_old column: 451 rows missing (6.7%)
# job_start_year column: 445 rows missing (6.7%)
# bio_urls column: 77 rows missing (1.2%)
# job_sequence column: 51 rows missing (0.76%)
# job_title column: 25 rows missing (0.37%)
# employer_name column: 3 rows missing (0.045%)
# job_category column: 3 rows missing (0.045%)
# employer_id column: 1 rows missing (0.015%)
# person_id column: 0 rows missing (0%)
# name column: 0 rows missing (0%)
# person_job_id column: 0 rows missing (0%)
# job_title_full column: 0 rows missing (0%)

# %%
# Get the rows of the given dataframe that are missing a value for the given column
def get_missing(df, col):
    return df[(df[col].isna()) 
              | (df[col].astype(str).str.startswith('can\'t find'))
              | (df[col].astype(str).str.startswith('missing'))]

# %% [markdown]
# ## 1.4 Term Frequency NLP
#
# This section processes and visualizes the most frequently occuring terms per job category, excluding the English stop words (words such as 'the' and 'of'). This gives an idea as to the main roles individuals in each job category are serving, and is used later to detect potential errors in job category placement.

# %%
# Find the k most frequent terms occuring in the given column of the given dataframe
# Input: df, column with category names, column with category terms (ex. job titles), name of category, k
def k_most_freq(df, col_cat, col_terms, cat, k):
    # Get the cells in the given category (with duplicates)
    cat_vals = df.loc[df[col_cat] == cat][col_terms]
    
    # Split each title and add each word to a list if it's not a stop word
    terms = []
    for title in cat_vals:
        if type(title) != float:
            for term in title.split():
                term_alnum = ''.join(c for c in term if c.isalnum() or c=='-') # Remove non-alnum characters (spaces, etc.)
                if (not term_alnum in stopwords.words('english')) and term_alnum: # If non-stopword and non-empty
                    terms.append(term_alnum)
                
    # Count the k most frequent terms in the job terms list             
    c = Counter(terms)
    return c.most_common(k)

# %%
# Input: df, column with category names, column with category terms, list of sorted column values, 
# name of cat col as string, name of term col as string, k (number of terms/bars per category), whether to display
def viz_kmf(df, col_cat, col_terms, cat_vals, k):
        
    n = len(cat_vals) # number of categories
    b = 3 if n < 10 else 4  # number of columns
    a = int(math.ceil(n / b))  # number of rows
    c = 1  # initialize plot counter

    colors = sns.color_palette("hls", n) # get a distinct color for each category

    fig = plt.figure(figsize=(22,16))
    
    # Create title strings from column names 
    cat_str = col_cat.replace('_', " ")
    term_str = col_terms.replace('_', " ")
    if not 'category' in cat_str:
        cat_str = cat_str.replace('cat', "category")

    # We'll also build a string doc representing the numerical data 
    doc = '\nThe ' + str(k) + ' most frequent ' + term_str + ' terms in each ' + cat_str.lower() + ' are:'

    for cat in cat_vals:
        freq = k_most_freq(df, col_cat, col_terms, cat, k)
        n = len(df.loc[df[col_cat] == cat])
        lab = cat + ' (n=' + str(n) + ')'

        # Add this category's k-most frequent terms to the growing doc
        doc += '\n' + lab
        for val in freq:
            doc += ('\n  - ' + val[0] + ': ' + str(val[1]))

        # Graph this category as a subplot
        ax = plt.subplot(a, b, c)
        plt.title(lab, fontsize=25)
        ax.tick_params(axis='x', which='major', labelsize=15)
        plt.xlabel('frequency', fontsize=20)

        # If this category doesn't have k values, add in some blank pads
        padded = (freq + [('', 0)] * k)[:k]

        plt.barh(range(k), [val[1] for val in padded], align='center', color=colors[c - 1])
        plt.yticks(range(k), [val[0] for val in padded], fontsize=15 if k < 16 else 12)
        ax.invert_yaxis()  # labels read top-to-bottom

        c = c + 1

    fig.suptitle(str(k) + ' Most Frequent ' + term_str.title() + ' Terms Per ' + cat_str.title(), fontsize=35)
    plt.tight_layout(rect=(0, 0, 1, 0.92), w_pad=1.5, h_pad=2.5)
    plt.savefig(out_ipynb + 'viz_' + col_cat + '_freq.png')
    plt.show()
    return doc

# %%
doc_jobs = viz_kmf(ind_jobs, 'job_category', 'job_title', job_cats, 10)

# %%
print(doc_jobs)
# Out:
# The 10 most frequent job title terms in each job category are:
# admin_leadership (n=1679)
#   - dean: 684
#   - vice: 472
#   - associate: 461
#   - provost: 395
#   - president: 381
#   - affairs: 215
#   - academic: 211
#   - college: 175
#   - interim: 171
#   - research: 146
# director_managerial (n=221)
#   - director: 209
#   - center: 53
#   - executive: 35
#   - research: 22
#   - associate: 20
#   - development: 19
#   - program: 17
#   - education: 16
#   - assessment: 15
#   - learning: 14
# chair_dept (n=416)
#   - chair: 330
#   - department: 259
#   - head: 60
#   - engineering: 35
#   - associate: 32
#   - interim: 29
#   - psychology: 16
#   - chemistry: 16
#   - sociology: 15
#   - science: 14
# director_research (n=308)
#   - director: 264
#   - center: 163
#   - research: 125
#   - institute: 56
#   - associate: 37
#   - co-director: 33
#   - science: 26
#   - education: 25
#   - evaluation: 24
#   - health: 18
# director_chair (n=244)
#   - director: 214
#   - program: 128
#   - studies: 72
#   - graduate: 36
#   - undergraduate: 26
#   - womens: 26
#   - school: 21
#   - chair: 18
#   - interim: 17
#   - department: 17
# director_diversity (n=140)
#   - director: 126
#   - advance: 42
#   - program: 42
#   - faculty: 30
#   - center: 25
#   - diversity: 22
#   - women: 22
#   - office: 16
#   - development: 16
#   - engineering: 15
# faculty (n=2276)
#   - professor: 2120
#   - full: 948
#   - associate: 612
#   - assistant: 478
#   - emeritus: 108
#   - plus: 82
#   - fellow: 23
# staff_management (n=163)
#   - coordinator: 50
#   - manager: 39
#   - program: 39
#   - project: 23
#   - assistant: 18
#   - research: 15
#   - advance: 13
#   - specialist: 11
#   - academic: 10
#   - advisor: 9
# staff_research (n=217)
#   - research: 162
#   - associate: 60
#   - scientist: 36
#   - researcher: 34
#   - assistant: 33
#   - senior: 30
#   - fellow: 29
#   - postdoctoral: 21
#   - professor: 19
#   - faculty: 9
# adjunct (n=229)
#   - professor: 94
#   - adjunct: 68
#   - visiting: 67
#   - instructor: 42
#   - faculty: 35
#   - lecturer: 35
#   - assistant: 30
#   - scholar: 12
#   - associate: 11
#   - department: 11
# postdoc (n=37)
#   - postdoctoral: 28
#   - fellow: 23
#   - associate: 4
#   - scholar: 4
#   - post-doctoral: 3
#   - post: 3
#   - doctoral: 2
#   - presidents: 2
#   - school: 2
#   - research: 2
# non-uni (n=730)
#   - director: 195
#   - president: 94
#   - consultant: 68
#   - program: 68
#   - senior: 66
#   - executive: 58
#   - vice: 43
#   - manager: 35
#   - research: 34
#   - ceo: 30
# deceased (n=24)
#   - deceased: 24

# %%
doc_roles = viz_kmf(ind_awards, 'award_role_cat', 'award_role', role_cats, 5)

# %%
print(doc_roles)
# Out:
# The 5 most frequent award role terms in each award role category are:
# grantee (n=1079)
#   - co-pi: 746
#   - pi: 328
#   - former: 227
#   - copi: 5
#   - kp: 2
# day-to-day (n=121)
#   - program: 50
#   - coordinator: 31
#   - director: 29
#   - project: 27
#   - manager: 23
# researcher (n=92)
#   - research: 59
#   - social: 43
#   - science: 43
#   - team: 42
#   - researcher: 31
# internal evaluator (n=105)
#   - internal: 103
#   - evaluator: 87
#   - evaluation: 19
#   - team: 10
#   - committee: 4
# external advisor (n=455)
#   - external: 434
#   - advisory: 399
#   - board: 372
#   - advisor: 51
#   - committee: 25
# external evaluator (n=124)
#   - external: 121
#   - evaluator: 114
#   - evaluation: 5
#   - group: 5
#   - possible: 5
# external consultant (n=48)
#   - consultant: 46
#   - external: 39
#   - equity: 3
#   - advisory: 2
#   - board: 2

# %% [markdown]
# ---
# ---
#
# <a id='two'></a>
#
# # 2. Data Cleaning & Pre-Processing
#
# Here, we clean the dataset for easier processing. This includes:
#
# - **Trimming extra spaces.** (Leading, trailing, double consecutive)
# - **Individual jobs' years and categories.** Since this is the main file we'll be looking at, we fill in missing year data with useful placeholders, and drop student/NaN job categories.
# - **Labeling universities and non-universities** A university is defined as an institution with a Carnegie ID or whose name contains one of several keywords.

# %% [markdown]
# ## 2.1 Space Trimming

# %%
# Trim the given dataframe, excluding the given list of columns
def trim_spaces(df, cols):
    df_exc = df.drop(cols, axis=1)
    cols = list(df_exc)
    
    for i, row in df.iterrows():
        for col in cols: # dataframe columns
            data = df[col][i] # get the ith element of column 
            if pd.isna(data):
                continue
            if isinstance(data, str):
                # Trim leading, trailing, and double-consecutive spaces
                trimmed = " ".join(data.split())  
                df.loc[i, col] = trimmed
                # if (data != trimmed):
                    # print(i, col, '\"' + data + '\" -> \"' + trimmed + '\"')

# %%
trim_spaces(ind_jobs, ['bio_urls'])
trim_spaces(ind_awards, [])
trim_spaces(ind_dems, [])
trim_spaces(orgs, [])

# %% [markdown]
# ## 2.2 Individal Jobs Cleaning
#
# We perform two sets of operations on the individual jobs file: the first should be reused for exporting the final individual jobs file later, and the second is only for this job processing task.
#
# First, we delete the jobs whose job category is student, as these should not exist in the dataset.
#
# Then, for job processing, we drop jobs which are missing a job category, or whose category is non-uni, and convert the missing start/end years in the individual jobs dataframe to min/max values.
#
# Note: Because of this, jobs without start years are considered non-lower-bounded and jobs without end years are considered non-upper-bounded. This allows us to consider positions that are missing this info when determining temporally relative position information.

# %%
def drop_students():
    before = len(ind_jobs)
    c_stud = 0
    body_stud = ''

    for i, row in ind_jobs.iterrows():
        cat = row['job_category']
        
        if cat == 'student':
            ind_jobs.drop(i, inplace=True)
            body_stud += 'person ' + str(row['person_id']) + ' has a student position in row ' + str(i) + '\n'
            list_student.append(row['person_id'])
            c_stud += 1

    ind_jobs.reset_index(inplace=True)

    out('\n' + str(c_stud) + ' students dropped for the jobs processing task.')
    out(' ')
    [out(line) for line in body_stud.splitlines()]

# %%
def clean_ind_jobs():
    before = len(ind_jobs)
    c_nan = 0
    c_start = 0
    c_end = 0
    body_nan = ''

    for i, row in ind_jobs.iterrows():
        cat = row['job_category']
        start = row['job_start_year']
        end = row['job_end_year']

        if pd.isna(cat):
            ind_jobs.drop(i, inplace=True)
            body_nan += 'person ' + str(row['person_id']) + ' has a no-category position in row ' + str(i) + '\n'
            list_nan.append(row['person_id'])
            c_nan += 1
            continue
        if pd.isna(start) or not str(int(start)).isnumeric():
            ind_jobs.loc[i, 'job_start_year'] = 0
            c_start += 1
        if pd.isna(end) or not str(end).isnumeric():
            ind_jobs.loc[i, 'job_end_year'] = 3000
            c_end += 1

    ind_jobs.reset_index(inplace=True)
    ind_jobs['job_start_year'] = pd.to_numeric(ind_jobs['job_start_year'])
    ind_jobs['job_end_year'] = pd.to_numeric(ind_jobs['job_end_year'])

    out('\n' + str(c_nan) + ' no-category positions dropped for the jobs processing task.')
    out(str(c_start) + ' start years were set to 0.')
    out(str(c_end) + ' end years were set to 3000.')
    out(' ')
    [out(line) for line in body_nan.splitlines()]

# %%
section(3, 'Student and NaN Job Categories')
drop_students()
out('\nThe jobs/demographics and individual awards for the individuals with student positions are located in:')
out('> log_student_jobs.csv, log_student_awards.csv\n')
out(LINE)
clean_ind_jobs()
out('\nThe jobs/demographics and individual awards for the individuals with NaN-category positions are located in:')
out('> log_nan_jobs.csv, log_nan_awards.csv files.')
# Out:
# 0 students dropped for the jobs processing task.
#
#
# The jobs/demographics and individual awards for the individuals with student positions are located in:
# > log_student_jobs.csv, log_student_awards.csv
#
# ------------------------------------------------------------------------------------------------------------------------
#
# 3 no-category positions dropped for the jobs processing task.
# 445 start years were set to 0.
# 1965 end years were set to 3000.
#
# person 1590 has a no-category position in row 2697
# person 1783 has a no-category position in row 3620
# person 2527 has a no-category position in row 6331
#
# The jobs/demographics and individual awards for the individuals with NaN-category positions are located in:
# > log_nan_jobs.csv, log_nan_awards.csv files.

# %% [markdown]
# ## 2.3 University Labeling
#
# #### We define an institution as a university if:
# - It has a corresponding Carnegie ID
# - It contains a university-related keyword (such as "university", "school")
#
# #### A non-university:
# - May contain an "antikey" (such as "school**s**", which is only used by associations of schools).
# - May contain the word "institute". This can be either a non-uni or a uni term: Indian Institute of Technology, Mumbai (uni) versus Space Telescope Science Institute (non-uni). Thus, we mark it as non-uni for now, and these have to manually be marked as uni.

# %%
# Return whether the given employer id corresponds to a university
def is_uni(emp_id):
    if pd.isna(emp_id):
        out('NaN employer')
        return False
        
    # If the employer is not in our list of organizations, return false.
    if not emp_id in orgs['org_id'].unique():
        out(str(emp_id) + ' is not in the organizations CSV')
        return False
    
    # Get the row corresponding to the given id in the organizations df
    org = orgs[orgs['org_id'] == emp_id].iloc[0]
    name = org['org_name'].lower() 
    
    # If the org has a Carnegie ID, then it is a US university 
    if not pd.isna(org['carnegie_id']):
        # out(name + ' has a Carnegie ID, so it\'s a US uni')
        return True
    
    # For non-US universities, we have keywords that we look for in the org's name
    keys = ['university', 'college', 'school', 'universitat', 'universidad', 'ecole']
            
    # We also have keys for non-unis that contain our uni keys, so we check for these first
    # Ex. "Cambridge Public Schools"
    antikeys = ['colleges', 'schools', 'association']    
    if any(x in name for x in antikeys):
        # out(name + ' contains an antikey, so it is not a uni')
        return False
    
    if any(x in name for x in keys):
        # out(name + ' contains a uni key, so it\'s a non-US uni')
        return True
    
    # The most tricky term seems to be "institute", as it can be either a non-uni or a uni term.
    # From manual review, we can see three institutes which are universities; these are marked here.
    if 'institute' in name and ('india' in name or 'stockholm' in name):
        # out(name + ' contains \'institute\' so it may or may not be a uni')
        return True
    
    # Else the org is not a US or non-US uni; return False
    # out(name + ' is not a uni')
    return False

# %%
out('', False)
section(4, 'Universities vs. Non-Universities')

us_unis = 0 # Count of US universities
for i, row in orgs.iterrows():
    orgs.loc[i, 'is_uni'] = is_uni(row['org_id'])
    us_unis += 1 if not pd.isna(row['carnegie_id']) else 0

out('\nNOTE: The organizations file should be reviewed, since the ASME Board of Governors improperly has a Carnegie ID value,')
out('so there may be other errors in this data.\n')
unis = len(orgs[orgs['is_uni']==True])
out(str(unis) + ' organizations are programmatically marked as universities. Of these, ' + str(us_unis) + ' are US universities, and ' + str(unis-us_unis) + ' are non-US.')
out(str(len(orgs[orgs['is_uni']==False])) + ' organizations are programmatically marked as non-universities.')
# Out:
# NOTE: The organizations file should be reviewed, since the ASME Board of Governors improperly has a Carnegie ID value,
# so there may be other errors in this data.
#
# 736 organizations are programmatically marked as universities. Of these, 620 are US universities, and 116 are non-US.
# 624 organizations are programmatically marked as non-universities.

# %% [markdown]
# ---
# ---
#
# <a id='three'></a>
#
# # 3. Error Detection
#
# We have a few potential errors we want to locate in the dataset. These include:
# - **University jobs at non-universities.** In the invididual jobs file, positions should be marked as non-uni if the employer is not a university as defined in 2.3.
# - **Date issues**. Start years must be <= end years for awards/jobs; jobs associated with the director of ADVANCE cannot start before the grant year.
# - **Job category placement.** We predict errors in job category placement based on job title terminology.

# %% [markdown]
# ## 3.1 University Jobs at Non-Universities
#
# We add to the report each non-university which has at least one employee with a university-labeled position, and set the listed position(s)' category to non-uni.

# %%
print('\nThe employers for the below positions are not presently marked as universities, so their categories will be set to non-uni.')

def mark_non_uni_jobs():
    body_uni = ''
    # If a job position is NOT marked as non-uni AND the corresponding employer is NOT a uni (by our definition)
    # Then there is an error -- the job should be marked as non-uni, since the employer is not a university.
    for i, row in orgs.iterrows():
        if row['is_uni'] == False:
            employees = ind_jobs[(ind_jobs['employer_id'] == row['org_id']) 
                                & (ind_jobs['job_category'] != 'non-uni')]
            if (len(employees) != 0):
                body_uni += '\n' + str(int(row['org_id'])) + ': ' + row['org_name']
                for i, row in employees.iterrows():
                    body_uni += '\n - ' + str(int(row['person_id'])) + ' had uni position: ' + row['job_category']
                    ind_jobs.loc[(ind_jobs['person_id']==row['person_id'])
                                 & (ind_jobs['job_title']==row['job_title'])
                                 & (ind_jobs['employer_id'] == row['employer_id']), 'job_category'] = 'non-uni'
    return body_uni

before = len(ind_jobs[ind_jobs['job_category']=='non-uni'])
body_uni = mark_non_uni_jobs()
after = len(ind_jobs[ind_jobs['job_category']=='non-uni'])
print('Number of jobs newly set to non-uni: ' + str(after-before))
print(body_uni)
# Out:
# The employers for the below positions are not presently marked as universities, so their categories will be set to non-uni.
# Number of jobs newly set to non-uni: 145
#
# 276732762: AAAS Education Program
#  - 2496 had uni position: director_managerial
# 2255342618: Agilent Technologies
#  - 2163 had uni position: admin_leadership
# 1991545139: American Association for Higher Education
#  - 2497 had uni position: admin_leadership
# 4105696068: American Association for the Advancement of Science
#  - 2495 had uni position: director_research
# 3532741284: American Association of Colleges of Pharmacy
#  - 1542 had uni position: admin_leadership
# 4141427435: American Association of University professors
#  - 2512 had uni position: staff_research
# 326288903: American Bar Foundation
#  - 2145 had uni position: staff_research
# 2724124343: American Chemical Society
#  - 1888 had uni position: deceased
# 1508303019: American Educational Research Association
#  - 2145 had uni position: director_managerial
# 2653734887: American Institute of Physics
#  - 1859 had uni position: director_research
#  - 1859 had uni position: director_research
#  - 1859 had uni position: director_research
# 39548561: American Society for Engineering Education
#  - 1381 had uni position: admin_leadership
# 2628653055: Area Education Agency
#  - 2490 had uni position: faculty
# 204489729: Association For Women in Mathematics
#  - 1724 had uni position: admin_leadership
#  - 1757 had uni position: director_managerial
# 4122554942: Association for Study of Higher Education
#  - 2048 had uni position: faculty
# 1696911125: Association for Women in Science, Inc.
#  - 1856 had uni position: deceased
# 1183998730: Association of American Colleges & Universities
#  - 1234 had uni position: admin_leadership
# 3768752512: Association of American Colleges and Universities
#  - 1234 had uni position: admin_leadership
# 3651265228: Association of Science-Technology Centers (ASTC)
#  - 2496 had uni position: director_managerial
# 4035146176: Association of Women ARC
#  - 1032 had uni position: adjunct
# 160457019: Bell Laboratories
#  - 2064 had uni position: admin_leadership
# 2369075653: Cambridge Public Schools
#  - 2196 had uni position: staff_research
# 4145800672: Carolina's Women Center, UNC
#  - 2080 had uni position: staff_management
# 546413280: Center for Child, Family, and Community Partnerships
#  - 2588 had uni position: staff_research
# 1132042999: Center for Economic Studies/Ifo Institute for Economic Research, Munich
#  - 1602 had uni position: staff_research
# 84831915: Center for Invasive Species Management
#  - 1414 had uni position: director_research
# 3189293577: Chemlinks
#  - 2542 had uni position: postdoc
# 737224584: Collective Health and Education Equity Research (CHEER)
#  - 2356 had uni position: director_research
# 2095672666: Cooper Ornithological Society
#  - 1037 had uni position: admin_leadership
# 800332291: Curb Center for Art, Enterprise, and Public Policy
#  - 1589 had uni position: staff_research
# 1349779573: Desert Research Institute
#  - 1458 had uni position: faculty
#  - 1458 had uni position: faculty
#  - 1727 had uni position: staff_research
# 2201267289: Development Systems International
#  - 1277 had uni position: admin_leadership
# 3471650375: Distinguished Professor of Urban Entrepreneurship, Management
#  - 2121 had uni position: faculty
# 2940522222: Eastman Kodak
#  - 2376 had uni position: director_research
# 426726679: Electronics and Engineering Technology, ITT Technical Institute
#  - 1937 had uni position: adjunct
# 3010942943: FAMU-FSU
#  - 1133 had uni position: admin_leadership
# 2973421276: Facebook
#  - 2031 had uni position: staff_research
# 203553486: Fred Hutchinson Cancer Research Center
#  - 1450 had uni position: postdoc
# 3277846768: GE Money Bank, Czech Republic
#  - 1975 had uni position: staff_management
# 3534170903: German Institute for Economic Research (DIW)
#  - 1602 had uni position: staff_research
# 39347560: Giancola Research Associates Inc.
#  - 2471 had uni position: admin_leadership
# 2421706704: Harvard Project on Faculty Appointments
#  - 1203 had uni position: staff_research
#  - 1203 had uni position: staff_management
# 993042960: High/Scope Educational Research Foundation
#  - 1985 had uni position: staff_research
# 708628000: Higher Education Resource Services
#  - 2242 had uni position: admin_leadership
# 2077061585: Hong Kong Institute of Education
#  - 1584 had uni position: faculty
# 3576676269: Hubrecht Laboratory, The Netherlands
#  - 1524 had uni position: adjunct
# 3184251285: IDA Science and Technology Policy Institute, Washington, D.C.
#  - 1357 had uni position: director_research
# 3821521381: IDEA Education
#  - 2531 had uni position: staff_research
# 3282481205: INSEAD
#  - 1426 had uni position: adjunct
# 48408390: ITT Technical Insistute
#  - 2501 had uni position: adjunct
# 2954224275: Institute for Learning Innovation
#  - 2337 had uni position: staff_research
#  - 2337 had uni position: staff_research
# 2049656374: Institute for Women's Policy Research
#  - 1477 had uni position: adjunct
#  - 1477 had uni position: director_research
#  - 1477 had uni position: admin_leadership
#  - 1477 had uni position: admin_leadership
#  - 2417 had uni position: director_research
# 3659532395: Institute for the Study of Labor (IZA), Bonn, Germany
#  - 1602 had uni position: staff_research
# 2294594468: Interdisciplinary Master's Degree in Community Development
#  - 1782 had uni position: admin_leadership
# 2443595195: Iowa Lakeside Laboratory
#  - 1037 had uni position: director_managerial
# 1779808756: J. Craig Venter Institute
#  - 2252 had uni position: director_research
#  - 2252 had uni position: admin_leadership
#  - 2252 had uni position: director_chair
# 1318473710: John D. and Catherine T. MacArthur Foundation
#  - 2059 had uni position: director_managerial
# 1998435611: King County, WA
#  - 2597 had uni position: staff_research
# 931443103: La Red de Fundaciones de Puerto Rico, Inc./ Puerto Rico Foundations Network
#  - 2192 had uni position: director_managerial
# 619558005: League of United Latin American Citizens (LULAC) of Greater Cincinnati
#  - 1107 had uni position: director_managerial
# 1491953783: Leveraging Immigrant Talent
#  - 2299 had uni position: staff_research
# 3656657997: Los Alamos National Laboratory, Camacho
#  - 1103 had uni position: postdoc
# 899162204: Marine Environmental Sciences Consortium
#  - 1668 had uni position: director_managerial
#  - 1668 had uni position: director_chair
#  - 1668 had uni position: faculty
# 2067314955: Max Planck Institute for Chemical Ecology
#  - 1011 had uni position: staff_research
# 1775092861: Metis Associates
#  - 2229 had uni position: staff_research
#  - 2311 had uni position: staff_research
# 2446180739: Microsoft
#  - 1724 had uni position: staff_research
# 2132560884: Monell Chemical Senses Center
#  - 1509 had uni position: staff_research
# 852469370: Mount Sinai
#  - 2438 had uni position: director_diversity
# 2033079871: NACME (National Action Council for Minorities in Engineering)
#  - 2092 had uni position: admin_leadership
# 322821670: NASA Ames Research Center
#  - 1458 had uni position: staff_research
# 2761588342: NASA's Jet Propulsion Laboratory
#  - 2595 had uni position: staff_research
# 3648168718: NSF TUES Central Resource Project
#  - 2201 had uni position: director_research
# 1800588816: National Academy of Engineering
#  - 2397 had uni position: director_diversity
# 2698280763: National Association for Research in Science Teaching
#  - 1854 had uni position: admin_leadership
# 4206132379: National Bureau of Economic Research
#  - 1483 had uni position: staff_research
# 780662563: National Institute of Ceramic Engineers
#  - 2386 had uni position: admin_leadership
# 3302659519: National Institute of Deafness
#  - 2589 had uni position: staff_research
# 3056813730: National Institutes of Health
#  - 1683 had uni position: director_chair
# 76703633: National Science Foundation
#  - 1225 had uni position: staff_research
#  - 1906 had uni position: adjunct
#  - 2280 had uni position: director_diversity
#  - 2585 had uni position: staff_research
# 2908245983: Nationwide Insurance
#  - 1021 had uni position: admin_leadership
# 1486552362: Naval Surface Warfare Center
#  - 1744 had uni position: staff_research
# 818050325: New Connections RWJF
#  - 2048 had uni position: faculty
# 1972269962: New England Research Institutes
#  - 1935 had uni position: staff_research
# 29362989: Non-uni
#  - 2291 had uni position: director_managerial
# 223880149: Northwest Regional Faculty Development Center at the Boise VA Medical Center.
#  - 2076 had uni position: staff_research
# 1980739554: Observatoire Oceanologique, Station Zoologique, Villefranche-sur-Mer, France
#  - 1193 had uni position: adjunct
# 1394314895: Oregon Social Learning Center
#  - 1471 had uni position: staff_research
# 3619735144: Pacific Center for Changing the Odds in Honolulu, HI, operated by Mid-Continent Research for Education and Learning
#  - 2413 had uni position: staff_research
# 3144022751: Pacific Institute for Research and Evaluation
#  - 2135 had uni position: staff_research
# 1260088225: Palo Alto Research Center
#  - 1765 had uni position: staff_research
# 1532210806: Philosophy IB
#  - 2031 had uni position: staff_research
# 4255018632: Policylink
#  - 2096 had uni position: faculty
# 176126377: Program in History of Science and Technology
#  - 2433 had uni position: director_chair
# 1817866274: RIT/ National Technical Institute for the Deaf
#  - 2287 had uni position: admin_leadership
#  - 2287 had uni position: faculty
# 227138889: Research Corporation for Science Advancement (RCSA)
#  - 2219 had uni position: admin_leadership
# 1927697649: Research Foundation CUNY
#  - 1373 had uni position: director_research
# 2389499242: Retired
#  - 1018 had uni position: faculty
# 2125199604: Salzburg Global Seminar
#  - 2497 had uni position: admin_leadership
# 1015687013: Shirley Ryan AbilityLab
#  - 1654 had uni position: staff_research
# 4282330987: Sigma Xi, The Scientific Research Society
#  - 2410 had uni position: director_diversity
# 225409658: Smithsonian Institute
#  - 1051 had uni position: staff_research
# 2374665956: Southwest Institute for Research on Women
#  - 2181 had uni position: director_managerial
#  - 2181 had uni position: faculty
#  - 2181 had uni position: staff_research
# 3973488011: Space Telescope Science Institute
#  - 2460 had uni position: chair_dept
# 1971179448: Spitzer Science Center
#  - 2520 had uni position: postdoc
# 2992050182: Summer Research Opportunities Program (SROP)
#  - 2492 had uni position: chair_dept
# 1599991266: Technical Education Research Centers
#  - 2363 had uni position: staff_research
# 807326559: The AWE Project
#  - 2017 had uni position: director_research
# 628025994: The Andrew W. Mellon Foundation
#  - 2123 had uni position: admin_leadership
# 3431356053: The Conference Board
#  - 2282 had uni position: staff_research
# 2445721098: The New Theater of Medicine
#  - 2203 had uni position: director_managerial
# 1584051212: The Ray Marshall Center for the Study of Human Resources
#  - 1715 had uni position: staff_research
# 1020016321: The Urban Institute
#  - 1715 had uni position: staff_research
#  - 2024 had uni position: director_research
# 741928967: US Army Research Laboratory
#  - 1023 had uni position: staff_research
#  - 1278 had uni position: director_managerial
# 54934735: West Virginia Experimental Program to Stimulate Competitive Research (WVEPSCoR)
#  - 2394 had uni position: director_managerial
# 988670977: West Virginia High Technology Consortium Foundation
#  - 2334 had uni position: director_chair
# 2032123687: West Virginia Higher Education Policy Commission
#  - 2394 had uni position: admin_leadership
#  - 2394 had uni position: admin_leadership
#  - 2394 had uni position: admin_leadership
# 357510143: Westat
#  - 2585 had uni position: staff_research
# 1708176772: Woods Hole Oceanographic Institution, Woods Hole
#  - 2465 had uni position: admin_leadership
# 546689643: missing
#  - 1610 had uni position: faculty
#  - 2564 had uni position: faculty
# 2379071406: precisionnumerics.com
#  - 2417 had uni position: staff_research

# %% [markdown]
# ## 3.2 Date Evaluation

# %%
# Since there's no output here, we can see that all job start years are less than their end years
for i, row in ind_jobs.iterrows():
    if row['job_start_year'] > row['job_end_year']:
        print(i)

# %%
out('', False)
section(5, 'Individual Award Date Issues')
out('\nThese individuals have at least one job associated with being director of an ADVANCE program which starts before they') 
out('entered the network.\n')

for i, row_job in ind_jobs.iterrows():
    # row_job['job_category'] == 'director_d'
    job_start = row_job['job_start_year']
    if job_start == 0:
        continue
    if type(row_job['job_title']) != float:
        title = row_job['job_title'].lower()
    if (title.endswith('advance') or 'advance ' in title) and 'director' in title:
        valid_director_job = False
        awards_slice = get_awards(row_job['person_id'])
        for i, row_award in awards_slice.iterrows():
            if job_start >= row_award['award_start_year']:
                valid_director_job = True
        if not valid_director_job:
            award_year = awards_slice['award_start_year'][awards_slice.index[0]]
            award_org = str(int(awards_slice['award_org_id'][awards_slice.index[0]]))
            title = title[:60] + '...' if len(title) > 60 else title
            out('Person ' + str(row_job['person_id'])
                  + ' has a job as \"' + title
                  + '\" which starts in year ' + str(int(job_start)) + '.')
            out('> Their first award started in ' + str(int(award_year)) + ' at org ' + award_org + '.')
# Out:
# These individuals have at least one job associated with being director of an ADVANCE program which starts before they
# entered the network.
#
# Person 1001 has a job as "director of the university of michigan advance program" which starts in year 1995.
# > Their first award started in 2002 at org 44098792.
# Person 1722 has a job as "director of lehigh's nsf-advance grant" which starts in year 2013.
# > Their first award started in 2015 at org 1213318465.
# Person 2110 has a job as "associate director, advance program" which starts in year 2011.
# > Their first award started in 2012 at org 4012281303.
# Person 2210 has a job as "acting director, advance program" which starts in year 2012.
# > Their first award started in 2018 at org 1397069697.
# Person 2210 has a job as "associate director, advance program, and director of the adv..." which starts in year 2014.
# > Their first award started in 2018 at org 1397069697.
# Person 2210 has a job as "director, advance program" which starts in year 2016.
# > Their first award started in 2018 at org 1397069697.
# Person 2293 has a job as "assistant director of ethnography & evaluation research, cen..." which starts in year 1995.
# > Their first award started in 2002 at org 3311607547.
# Person 2359 has a job as "director, adapp-advance" which starts in year 2008.
# > Their first award started in 2018 at org 1397069697.

# %% [markdown]
# ## 3.3 Prediction of Job Category Misplacement
#
# We seek to detect in this section job category misplacement via our k-most-frequent algorithm, and through searching for category-specific keys and antikeys.
#
# For example, we expect administrators to fall into high-level positions such as dean and provost, so we want to mark for manual review those positions marked admin which contain such terms as "advisor" and "liaison", as these aren't top-level administrative positions.

# %%
job_cats_misp = job_cats.copy()
job_cats_misp.remove('non-uni')
#job_cats_misp.remove('student')
sort_jobs(job_cats_misp)

freq_dict = {cat: k_most_freq(ind_jobs, 'job_category', 'job_title', cat, 15) for cat in job_cats_misp}

# %%
keys_dict = {'admin_leadership': ['chief', 'ceo'],
             'director_managerial': [],
             'chair_dept': ['chairman'],
             'director_chair': [],
             'director_research': [],
             'director_diversity': [],
             'faculty': ['lecturer', 'scientist', 'instructor'],
             'staff_management': ['research', 'researcher', 'advisor'],
             'staff_research': [],
             'adjunct': [],
             'postdoc': ['postdoc'],
             'deceased': []}

antikeys_dict = {'admin_leadership': ['advisor', 'liaison'],
                 'director_managerial': ['advisor', 'liaison'],
                 'chair_dept': [],
                 'director_chair': [],
                 'director_research': [],
                 'director_diversity': [],
                 'faculty': [],
                 'staff_management': [],
                 'staff_research': [],
                 'adjunct': [],
                 'postdoc': [],
                 'deceased': []}

# %%
out('', False)
section(6, 'Predicting Job Category Misplacement')
out('\nFor each category, we output the job titles which contain neither the 15 most frequent terms in their assigned category nor '
    + 'any of the manually defined category keys. This also points to some misspelled job titles, such as \"profesor\".')

for cat in job_cats_misp:
    keys = [tup[0] for tup in freq_dict[cat]]
    keys = keys + keys_dict[cat]
    antikeys = antikeys_dict[cat]
    cat_slice = ind_jobs.loc[ind_jobs['job_category'] == cat]
    
    out('\nJob titles which may not fit in category ' + cat + ': ')
    for i, row in cat_slice.iterrows():
        if type(row['job_title']) != float:
            terms = re.split(',|, |_|-| |:|/', row['job_title']) 
            if (not any(term in keys for term in terms)) or any(term in antikeys for term in terms):
                out('Person ' + str(int(row['person_id'])) + ': ' + row['job_title'])
# Out:
# For each category, we output the job titles which contain neither the 15 most frequent terms in their assigned category nor any of the manually defined category keys. This also points to some misspelled job titles, such as "profesor".
#
# Job titles which may not fit in category admin_leadership:
# Person 1018: special advisor to the president
# Person 1021: organizational change management director
# Person 1052: special advisor to the vice-president academic on faculty development
# Person 1053: special advisor to provost for gender
# Person 1121: wellness programs administrator
# Person 1130: prem program director
# Person 1131: deputy director
# Person 1167: advisor to the president
# Person 1198: budget director
# Person 1239: director, the ethos center
# Person 1343: ciesin senior fellow
# Person 1357: director and professor of statistics
# Person 1386: senior advisor
# Person 1386: senior advisor to the president
# Person 1389: special advisor on research development and external partnerships
# Person 1420: school head
# Person 1467: senior advisor for faculty affairs, office of the provost
# Person 1579: special advisor to the provost for women's leadership
# Person 1761: campus executive officer
# Person 1845: medical director, quality
# Person 1872: executive director of the office for economic development and innovations management
# Person 1909: executive coordinator
# Person 1951: faculty liaison, academic and research computing
# Person 1960: ombudsperson
# Person 2066: faculty liaison for tisch college
# Person 2095: advisory board member
# Person 2193: senior advisor to the president
# Person 2244: vp for institutional diversity
# Person 2271: co-chair, bystander intervention committee, stride, advancement of women, equity, and diversity
# Person 2286: executive-in-residence
# Person 2359: senior advisor to the dean for research mentoring at the graduate school
# Person 2419: assistant vice chancellor for academic affairs, and cic campus liaison
# Person 2509: hurlburt chair of mis, school of management
# Person 2519: advisor and founding member, office of continuous improvement and assessment
# Person 2589: university senate chair
# Person 2608: advance program leader
# Person 2609: advance program leader
#
# Job titles which may not fit in category director_managerial:
# Person 1322: chair of the faculty
# Person 1415: asme’s board of governors
# Person 1718: chair of the faculty
# Person 1831: faculty assembly chair, department of computer and electrical engineering and computer science
# Person 1844: founder, uhealth
# Person 2493: vice chair, utpa women faculty network leadership team
#
# Job titles which may not fit in category chair_dept:
#
# Job titles which may not fit in category director_research:
# Person 1532: co-founder brains and lattice
#
# Job titles which may not fit in category director_chair:
#
# Job titles which may not fit in category director_diversity:
#
# Job titles which may not fit in category faculty:
#
# Job titles which may not fit in category staff_management:
# Person 1226: evaluation specialist. center for water and environmental sustainability.
# Person 1226: associate director, institute for natural resources
# Person 1236: administrator
# Person 1301: administrator
# Person 1673: pre-doctoral intern
# Person 1712: clinical psychologist
# Person 1809: facilitator for outcomes assessment
# Person 1907: volunteer
# Person 1975: administrator
# Person 1991: grant writer
# Person 1992: reasearch associate
# Person 2015: counselor
# Person 2040: rector
# Person 2098: associate for special projects
# Person 2194: webmaster
# Person 2205: office of instruction and assessment
# Person 2273: curriculum editor
# Person 2290: intern
# Person 2290: scholarly communication librarian
# Person 2297: administrative secretary
# Person 2452: author
# Person 2473: information technologist
#
# Job titles which may not fit in category staff_research:
# Person 1044: wolfe chair, scientific and technological literacy
#
# Job titles which may not fit in category adjunct:
#
# Job titles which may not fit in category postdoc:
# Person 2585: education coach
#
# Job titles which may not fit in category deceased:

# %% [markdown]
# ---
# ---
#
# <a id='four'></a>
#
# # 4. Locating First, Highest, and Latest Positions
#
# In this section, we locate the first, highest, and latest positions for our network members, at both the individual and award-role levels. In all cases, two invariants are used:
# 1. We filter through the job years based on the point at which an individual entered the ADVANCE Network, where entrance is defined as having an award role in our dataset. This is to account for the cases in which our job records for a given person extend beyond their first ADVANCE grant role.
# 2. In the cases of ties (ex. two jobs which start and end in the same respective years), we tie-break using the job hierarchy defined in section 1.2.
#
# ### At the individual (person) level:
# - An individual's **first** position is the best guess at the position they had upon entering the network.
# - An individual's **highest** position is the highest position they had throughout their career after entering the network.
# - An individual's **last** position is the most recent position they had.
#
# ### At the award (role) level:
# - An award member's **first** position is the best guess at the position they had upon joining the given grant.
# - An award member's **highest** position is the best guess at the highest position they had throughout their involvement in the given grant.
# - An award member's **last** position is the best guess at the last position they had while working on the given grant.

# %%
# Optional: Filter out the non-university positions
def drop_non_unis():
    non_unis = len(ind_jobs[ind_jobs['job_category']=='non-uni'])

    for i, row in ind_jobs.iterrows():
        if row['job_category'] == 'non-uni':
            ind_jobs.drop(i, inplace=True)

    #ind_jobs.reset_index(inplace=True)
    print('We dropped ' + str(non_unis) + ' non-university positions.')
    
# drop_non_unis()

# %%
# Get the year and job of the given person when they first entered the ADVANCE network (via the first grant they worked on)
# Input: an individual's id, the year of the person's first grant they worked on, and the institution of their first grant
# Return the first job and first year in the network of the given person
def get_first_job(p_id, first_year, e_id, award_start_year=0, award_end_year=3000):    
    ind = -1
    # Person-level: filter using the institution id for their first grant (which started in first_year)
    if award_start_year == 0:
        jobs_slice = ind_jobs.loc[(ind_jobs['person_id'] == p_id)
                                  & (ind_jobs['employer_id'] == e_id)
                                  & (ind_jobs['job_start_year'] <= first_year)
                                  & (ind_jobs['job_end_year'] >= first_year)
                                 ].sort_values(by = 'job_start_year') 
       
    # Role-level: filter using the given award start/end year and id, and the year they entered the network
    else:
        # Get the jobs for this p_id at the given e_id where all job years are around the award time
        # The job cannot start after the award ends, or end before the award starts
        jobs_slice = ind_jobs.loc[(ind_jobs['person_id'] == p_id)
                                  & (ind_jobs['employer_id'] == e_id)
                                  & (ind_jobs['job_start_year'] <= award_end_year)
                                  & (ind_jobs['job_end_year'] >= award_start_year)
                                 ].sort_values(by = 'job_start_year') 
            
        # Get the jobs which didn't end before the award started 
        if len(jobs_slice) == 0:
            ind = 0
            jobs_slice = ind_jobs.loc[(ind_jobs['person_id'] == p_id)
                                      & (ind_jobs['job_end_year'] >= award_start_year)
                                      ].sort_values(by = 'job_start_year') 
            
    # If there are no jobs found which start before or during the first or given award start year, 
    # then get the first job at the given award institution (which didn't end before the award started)
    if len(jobs_slice) == 0:                
        jobs_slice = ind_jobs.loc[(ind_jobs['person_id'] == p_id)
                                  & (ind_jobs['employer_id'] == e_id)
                                  & (ind_jobs['job_end_year'] >= first_year)
                                 ].sort_values(by = 'job_start_year')
        ind = 0

        # If there are no jobs at the first or given award institution,
        # then get the closest job which started at or before the year they entered the network
        # but did not end before they entered the network
        if len(jobs_slice) == 0:
            jobs_slice = ind_jobs.loc[(ind_jobs['person_id'] == p_id)
                                      & (ind_jobs['job_start_year'] <= first_year)
                                      & (ind_jobs['job_end_year'] >= first_year)
                                     ].sort_values(by = 'job_start_year') 
            ind = -1

            # If the person has no jobs which start at or before their entrance into the network (person-Level),
            # or within the given award period (role-level), get the first job for this person after entrance
            if len(jobs_slice) == 0:
                jobs_slice = ind_jobs.loc[(ind_jobs['person_id'] == p_id)
                                          & (ind_jobs['job_end_year'] >= first_year)
                                         ].sort_values(by = 'job_start_year')
                ind = 0
                
                # If all their jobs end before they enter the network, just get the most recent job they had
                if len(jobs_slice) == 0:
                    jobs_slice = get_jobs(p_id)
                    ind = -1

                    # If there are still no jobs, return NaN
                    if (len(jobs_slice) == 0):
                        return np.nan

    # Ascending order --> take either the jobs in the first year or the last one (if need leq closest to award year)
    first_job_year = jobs_slice['job_start_year'][jobs_slice.index[ind]]

    # Get all rows in the dataframe slice that contain the first year
    jobs_first_year_slice = jobs_slice.loc[ind_jobs['job_start_year'] == first_job_year]

    # Find the highest position of all the first-year jobs
    jobs_list = jobs_first_year_slice['job_category'].drop_duplicates().to_list()
    jobs_list = [x for x in jobs_list if str(x) != 'nan']
    highest_title = get_highest_title(jobs_list)
    return highest_title

# %%
# Get the best estimate for the highest job of the given person after they entered the ADVANCE network.
# If an employer id is given, we are working at the role level -> Find the highest job they had during/around the award.
# Input: an individual's id, and (optionally) an employer id to filter by
def get_highest_job(p_id, first_year, e_id=None, award_start_year=0, award_end_year=3000):
    
    # Person-level: get the jobs they had after entering the ADVANCE network
    if e_id is None: 
        jobs_slice = ind_jobs[(ind_jobs['person_id'] == p_id)
                              & (ind_jobs['job_end_year'] >= first_year)]
        
    # Role-level: get the jobs they had at the given award institution
    # The jobs cannot start after the given award ends, or end before the award starts
    else:
        jobs_slice = ind_jobs.loc[(ind_jobs['person_id'] == p_id)
                                      & (ind_jobs['employer_id'] == e_id)
                                      & (ind_jobs['job_start_year'] <= award_end_year)
                                      & (ind_jobs['job_end_year'] >= award_start_year)]
            
    # If there are no jobs found, then just get the jobs they had after they entered the ADVANCE network 
    if len(jobs_slice) == 0:
        jobs_slice = ind_jobs[(ind_jobs['person_id'] == p_id) 
                              & (ind_jobs['job_end_year'] >= first_year)]
        
        # If they have no jobs after entering the network, then just get the highest job that this person ever had
        if len(jobs_slice) == 0:
            jobs_slice = ind_jobs[ind_jobs['person_id'] == p_id]
            
            # If still no jobs, return NaN
            if len(jobs_slice) == 0: 
                return np.nan
    
    jobs_list = jobs_slice['job_category'].drop_duplicates().to_list()
    jobs_list = [x for x in jobs_list if str(x) != 'nan']
    return get_highest_title(jobs_list)

# %%
# Get the year and job of the given person when they first entered the ADVANCE network (via the first grant they worked on)
# Input: an individual's id, the year of the person's first grant they worked on, and the institution of their first grant
# Return the first job and first year in the network of the given person
def get_last_job(p_id, first_year, e_id=None, award_start_year=0, award_end_year=3000):
    
    # If we're working at the person level, get all the jobs they had after entering the network
    if e_id is None:
        jobs_slice = ind_jobs.loc[(ind_jobs['person_id'] == p_id) 
                                  & (ind_jobs['job_end_year'] >= first_year)
                                 ].sort_values(by = 'job_start_year') 

    # If we're working at the role level, get jobs they during and after the given award
    # and use the employer id of the given award for best estimate
    else:
        # Get the jobs for this p_id at the given e_id around the time of the award;
        # The job cannot start after the award ends, or end before the award starts
        jobs_slice = ind_jobs.loc[(ind_jobs['person_id'] == p_id)
                                  & (ind_jobs['job_start_year'] <= award_end_year) # job start <= award end 
                                  & (ind_jobs['job_end_year'] >= award_start_year) # job end >= award start
                                  & (ind_jobs['employer_id'] == e_id)
                                 ].sort_values(by = 'job_start_year') 
    
        # If there are no jobs at the given award institution, find the closest job around the award period
        if len(jobs_slice) == 0:
            jobs_slice = ind_jobs.loc[(ind_jobs['person_id'] == p_id)
                                      & (ind_jobs['job_start_year'] <= award_end_year)
                                      & (ind_jobs['job_end_year'] >= award_start_year)
                                     ].sort_values(by = 'job_start_year') 

    # If there are no jobs >= the award start year, just get the highest job for this person
    if len(jobs_slice) == 0:
        jobs_slice = get_jobs(p_id)

        # If there are still no jobs, return NaN
        if (len(jobs_slice) == 0):
            return np.nan

    # Get the most recent job start year, and keep only the jobs that start in that year
    last_start_year = jobs_slice['job_start_year'][jobs_slice.index[-1]]
    jobs_last_start_year = jobs_slice.loc[ind_jobs['job_start_year'] == last_start_year].sort_values('job_end_year')
    
    # Get the most recent job end year, and keep only the jobs with the latest start AND end years
    last_end_year = jobs_last_start_year['job_end_year'][jobs_slice.index[-1]]
    jobs_last_start_and_end_year = jobs_last_start_year.loc[ind_jobs['job_end_year'] == last_end_year]
    
    # Break ties among multiple last jobs using the job category hierarchy
    jobs_list = jobs_last_start_and_end_year['job_category'].drop_duplicates().to_list()
    jobs_list = [x for x in jobs_list if str(x) != 'nan']
    highest_title = get_highest_title(jobs_list)
    return highest_title

# %%
# Output a breakdown of the given log df (level = a string title for the data in the df)
def out_log_task_breakdown(df, level):
    missing = df[(df['first_job'].isna())
                 | (df['highest_job'].isna())
                 | (df['last_job'].isna())].copy()

    n = len(df)
    missing_any = len(missing)
    missing_first = df['first_job'].isna().sum()
    missing_highest = df['highest_job'].isna().sum()
    missing_last = df['last_job'].isna().sum()

    perc_filled = 100-(100*missing_any/n)
    perc_first = 100*(missing_first)/n
    perc_highest = 100*(missing_highest)/n
    perc_last = 100*(missing_last)/n

    # Analysis for individuals with found data -----------------------------------------------

    out('\nFound first, highest, and last positions for ' + f'{perc_filled:.2g}%' + ' of the ' + str(n) + ' ' + level + ' in our records. (n=' + str(n - missing_any) + ')')

    # print(str(ties) + ' individuals have more than one award in their first year in the ADVANCE Program.') 
    # print(doc_tie) for a list of these individuals

    def out_job_breakdown(col):
        for cat in job_cats:
            # Get the number of individuals whose given position were in this category
            count = len(df[df[col] == cat].copy())
            perc = 100*count/(n-missing_any)
            out(f'{perc:.1f}% ' + cat + ' positions (n=' + str(count) + ')')
    
    out('\nThe first jobs of these ' + level + ' are:')
    out_job_breakdown('first_job')
    out('\nThe highest jobs of these ' + level + ' are:')
    out_job_breakdown('highest_job')
    out('\nThe last jobs of these ' + level + ' are:')
    out_job_breakdown('last_job')

    # Analysis for individuals missing data -----------------------------------------------

    out(' ')
    out(LINE)
    out(' ')
    if (missing_first == missing_highest == missing_last): 
        out(str(missing_any) + ' ' + level + ' are missing first, highest, and last positions.')
    else:
        out(str(missing_first) + ' ' + level + ' are missing first positions out of ' +
              str(n) + ' ' + level + '. ' + f'({perc_first:.2g}% filled)')
        out(str(missing_highest) + ' ' + level + ' are missing highest positions out of ' +
              str(n) + ' ' + level + '. ' + f'({perc_highest:.2g}% filled)')
        out(str(missing_last) + ' ' + level + ' are missing last positions out of ' + 
              str(n) + ' ' + level + '. ' + f'({perc_last:.2g}% filled)')

    # Get the people who are missing data in at least one of the job categories 
    out('\nOf the ' + str(missing_any) + ' ' + level + ' missing at least one of these positions,')

    # Of those, see how many people have no non-uni/student/NaN jobs
    no_jobs = 0
    for i, row in missing.iterrows():
        jobs = get_jobs(row['person_id'])
        if len(jobs) == 0:
            no_jobs += 1
    no_jobs_perc = 100*no_jobs/missing_any
    out(f'{no_jobs_perc:.3g}%' + ' have zero jobs which are not categorized as student/NaN. (n=' + str(no_jobs) + ')')   

    # Get all the awards for those individuals, and output distribution of award roles
    awards_missing_ind = ind_awards[ind_awards['person_id'].isin(missing['person_id'])]
    
    for cat in role_cats:
        # Get the number of individuals who had at least one position in this award role category
        cat_awards_slice = awards_missing_ind[awards_missing_ind['award_role_cat'] == cat].copy().drop_duplicates('person_id')
        cat_count = len(cat_awards_slice)
        cat_perc = 100*cat_count/missing_any
        out(f'{cat_perc:.2g}%' + ' have at least one ' + cat + ' award role. (n=' + str(cat_count) + ')')

# %% [markdown]
# ## 4.1 Person Level
#
# Given the cleaned dataset, we find first, highest, and latest positions for 100% of individuals with at least one categorizable, non-student position. We output a set of 14 individuals (<1% of overall) whose records necessitate further research.

# %%
# For each individual, get the first, highest, and last jobs

ties = 0
doc_tie = ''

for i, row in log_individual_jobs.iterrows():
    p_id = row['person_id']
    awards_slice = get_awards(p_id)
    
    # Ascending order --> first row has year and institution of the first award this person worked on
    ind_first = awards_slice.index[0]
    year_first = awards_slice['award_start_year'][ind_first]
    log_individual_jobs.loc[i, 'first_year_in_advance'] = year_first
    
    # If individuals started at two different grants in the same years, pick the one where they had the highest role
    awards_year_first = awards_slice.loc[awards_slice['award_start_year'] == year_first].copy()
    awards_year_first.drop_duplicates('award_org_id', inplace=True)
    if len(awards_year_first) > 1:
        awards_year_first['award_role_cat'] = awards_year_first['award_role_cat'].map(role_dict).argsort()
        e_id_first = awards_year_first['award_org_id'][awards_year_first.index[-1]]
        # doc_tie += 'Person ' + str(p_id) + '\'s highest role was at org ' + str(e_id_first) + '\n'
        ties += 1
    else: 
        e_id_first = awards_slice['award_org_id'][ind_first]
    
    # Get the first, highest, and last jobs    
    log_individual_jobs.loc[i, 'first_job'] = get_first_job(p_id, year_first, e_id_first)
    log_individual_jobs.loc[i, 'highest_job'] = get_highest_job(p_id, year_first)
    log_individual_jobs.loc[i, 'last_job'] = get_last_job(p_id, year_first)

# %%
out('', False)
section(7, 'Location of First, Highest, and Last Jobs')
out_log_task_breakdown(log_individual_jobs, 'individuals')
out('\nThe jobs/demographics and individual awards for the individuals missing positions are located in:')
out('> log_missing_jobs.csv, log_missing_awards.csv')
# Out:
# Found first, highest, and last positions for 96% of the 1590 individuals in our records. (n=1524)
#
# The first jobs of these individuals are:
# 26.8% admin_leadership positions (n=408)
# 3.0% director_managerial positions (n=46)
# 7.2% chair_dept positions (n=109)
# 5.1% director_research positions (n=77)
# 3.3% director_chair positions (n=51)
# 3.0% director_diversity positions (n=46)
# 35.4% faculty positions (n=540)
# 2.8% staff_management positions (n=42)
# 3.4% staff_research positions (n=52)
# 1.5% adjunct positions (n=23)
# 0.3% postdoc positions (n=4)
# 8.1% non-uni positions (n=124)
# 0.1% deceased positions (n=2)
#
# The highest jobs of these individuals are:
# 41.8% admin_leadership positions (n=637)
# 5.8% director_managerial positions (n=88)
# 9.7% chair_dept positions (n=148)
# 6.4% director_research positions (n=97)
# 2.9% director_chair positions (n=44)
# 2.6% director_diversity positions (n=40)
# 21.5% faculty positions (n=328)
# 1.8% staff_management positions (n=27)
# 1.8% staff_research positions (n=27)
# 0.5% adjunct positions (n=8)
# 0.3% postdoc positions (n=4)
# 5.0% non-uni positions (n=76)
# 0.0% deceased positions (n=0)
#
# The last jobs of these individuals are:
# 26.8% admin_leadership positions (n=409)
# 3.3% director_managerial positions (n=51)
# 6.0% chair_dept positions (n=92)
# 4.7% director_research positions (n=72)
# 2.3% director_chair positions (n=35)
# 2.0% director_diversity positions (n=31)
# 32.7% faculty positions (n=498)
# 2.3% staff_management positions (n=35)
# 2.4% staff_research positions (n=37)
# 1.9% adjunct positions (n=29)
# 0.2% postdoc positions (n=3)
# 13.9% non-uni positions (n=212)
# 1.3% deceased positions (n=20)
#
# ------------------------------------------------------------------------------------------------------------------------
#
# 66 individuals are missing first, highest, and last positions.
#
# Of the 66 individuals missing at least one of these positions,
# 100% have zero jobs which are not categorized as student/NaN. (n=66)
# 1.5% have at least one grantee award role. (n=1)
# 82% have at least one day-to-day award role. (n=54)
# 1.5% have at least one researcher award role. (n=1)
# 1.5% have at least one internal evaluator award role. (n=1)
# 6.1% have at least one external advisor award role. (n=4)
# 6.1% have at least one external evaluator award role. (n=4)
# 3% have at least one external consultant award role. (n=2)
#
# The jobs/demographics and individual awards for the individuals missing positions are located in:
# > log_missing_jobs.csv, log_missing_awards.csv

# %% [markdown]
# ## 4.2 Role Level

# %%
# For each individual award role, get the first, highest, and last jobs

log_individual_awards.insert(4, 'award_end_year', None)

for i, row in log_individual_awards.iterrows():
    # Get all the award role categories this person had for this award, and pick the highest
    awards_slice = get_awards(row['person_id'])
    awards_org_slice = awards_slice[(awards_slice['award_id'] == row['award_id'])] 
    roles_list = awards_org_slice['award_role_cat'].drop_duplicates().to_list()
    roles_list = [x for x in roles_list if str(x) != 'nan']
    log_individual_awards.loc[i, 'award_role_cat'] = get_highest_role(roles_list)

    # Get the first award role title which corresponds to this award role category
    first_highest_title = awards_org_slice['award_role'].drop_duplicates().to_list()[0]
    log_individual_awards.loc[i, 'award_role'] = first_highest_title
        
log_individual_awards = log_individual_awards.drop_duplicates(['person_id', 'award_id'])

for i, row in log_individual_awards.iterrows():
    p_id = row['person_id']
    first_year = log_individual_jobs.loc[log_individual_jobs['person_id']==p_id, 'first_year_in_advance'].iloc[0]
    e_id = row['award_org_id']
    award_start_year = row['award_start_year']
    award_row = awards.loc[(awards['award_start_year']==award_start_year) & (awards['awarded_org_id']==e_id)
                                , 'award_end_year']
    award_end_year = award_row.iloc[0] if len(award_row) > 0 else 3000
    log_individual_awards.loc[i, 'award_end_year'] = award_end_year
    log_individual_awards.loc[i, 'first_job'] = get_first_job(p_id, first_year, e_id, award_start_year, award_end_year)
    log_individual_awards.loc[i, 'highest_job'] = get_highest_job(p_id, first_year, e_id, award_start_year, award_end_year)
    log_individual_awards.loc[i, 'last_job'] = get_last_job(p_id, first_year, e_id, award_start_year, award_end_year)

# %%
out(' ', False)
out(LINE, False)
out_log_task_breakdown(log_individual_awards, 'individual award roles')
# Out:
# Found first, highest, and last positions for 97% of the 2024 individual award roles in our records. (n=1957)
#
# The first jobs of these individual award roles are:
# 27.5% admin_leadership positions (n=538)
# 4.0% director_managerial positions (n=79)
# 5.8% chair_dept positions (n=113)
# 4.3% director_research positions (n=85)
# 2.7% director_chair positions (n=52)
# 4.0% director_diversity positions (n=78)
# 34.9% faculty positions (n=683)
# 2.5% staff_management positions (n=48)
# 2.7% staff_research positions (n=52)
# 1.6% adjunct positions (n=32)
# 0.2% postdoc positions (n=3)
# 9.5% non-uni positions (n=186)
# 0.4% deceased positions (n=8)
#
# The highest jobs of these individual award roles are:
# 39.3% admin_leadership positions (n=769)
# 5.9% director_managerial positions (n=116)
# 9.0% chair_dept positions (n=177)
# 5.9% director_research positions (n=116)
# 2.5% director_chair positions (n=48)
# 3.4% director_diversity positions (n=67)
# 23.7% faculty positions (n=464)
# 1.8% staff_management positions (n=36)
# 2.0% staff_research positions (n=40)
# 0.8% adjunct positions (n=15)
# 0.2% postdoc positions (n=4)
# 5.4% non-uni positions (n=105)
# 0.0% deceased positions (n=0)
#
# The last jobs of these individual award roles are:
# 28.0% admin_leadership positions (n=547)
# 3.8% director_managerial positions (n=75)
# 6.8% chair_dept positions (n=134)
# 4.5% director_research positions (n=88)
# 2.3% director_chair positions (n=45)
# 3.5% director_diversity positions (n=68)
# 32.6% faculty positions (n=638)
# 2.5% staff_management positions (n=49)
# 2.6% staff_research positions (n=50)
# 1.7% adjunct positions (n=34)
# 0.2% postdoc positions (n=3)
# 11.0% non-uni positions (n=216)
# 0.5% deceased positions (n=10)
#
# ------------------------------------------------------------------------------------------------------------------------
#
# 67 individual award roles are missing first, highest, and last positions.
#
# Of the 67 individual award roles missing at least one of these positions,
# 100% have zero jobs which are not categorized as student/NaN. (n=67)
# 1.5% have at least one grantee award role. (n=1)
# 81% have at least one day-to-day award role. (n=54)
# 1.5% have at least one researcher award role. (n=1)
# 1.5% have at least one internal evaluator award role. (n=1)
# 6% have at least one external advisor award role. (n=4)
# 6% have at least one external evaluator award role. (n=4)
# 3% have at least one external consultant award role. (n=2)

# %% [markdown]
# ## 4.3 Visualization of Job Categories

# %%
job_cats_viz = job_cats.copy()
#job_cats_viz.remove('student')
sort_jobs(job_cats_viz)

def viz_triple_pie(df, name):
    levels = ['first', 'highest', 'last']
    COLORS = list(sns.color_palette("hls", len(job_cats) - 1))
    COLORS.append('lightpink')
    TEXT_COLOR = 'black'
    c = 1
    fig = plt.figure(figsize=(28,12))

    for level in levels:
        # Create a new dataframe to store the quantities of each subbar
        df_q = pd.DataFrame(columns=['cat_' + level, 'total'])

        # Add the quantity of each category to the quantity dataframe
        for cat in job_cats_viz:
            total = len(df[df[(level + '_job')] == cat].copy())
            df_q = df_q.append({'cat_' + level: cat, 'total': total},ignore_index=True)

        def format_label(cat):
            count = df_q.loc[df_q['cat_' + level]==cat, 'total'].iloc[0]
            perc = 100*count/df_q['total'].sum()
            return cat + f': {perc:.1f}%'

        # Graph this category as a subplot
        ax = plt.subplot(1, 3, c)
        plt.title(level.title() + ' Jobs', fontsize=40, color=TEXT_COLOR)

        texts = ax.pie(df_q['total'], colors=COLORS, startangle=90, wedgeprops=dict(linewidth=2, edgecolor='w'))
        plt.rcParams['text.color'] = TEXT_COLOR

        # Make the legend
        custom_lines = [Line2D([0], [0], color=c, marker="s", markersize=12, linewidth=0, label=format_label(lab)) 
                        for c, lab in zip(COLORS, df_q['cat_' + level])]
        leg = plt.legend(handles=custom_lines, loc="center", ncol=2, framealpha=0, bbox_to_anchor=(0.55, -0.2))
        for text in leg.get_texts():
            plt.setp(text, color = TEXT_COLOR, fontsize=22)

        c += 1

    fig.suptitle("Job Categories for University ADVANCE Network Individuals, " 
                 + name.title() + "-Level (n=" + str(sum(df_q['total'])) + ")", fontsize=46)
    fig.tight_layout()
    plt.savefig(out_ipynb + 'viz_log_individual_jobs_' + name + '.png', dpi=fig.dpi)
    plt.show()

# %%
viz_triple_pie(log_individual_jobs, 'person')

# %%
viz_triple_pie(log_individual_awards, 'role')

# %% [markdown]
# # 4.4 FINAL OUTPUT

# %%
missing = log_individual_jobs[(log_individual_jobs['first_job'].isna())
                              | (log_individual_jobs['highest_job'].isna())
                              | (log_individual_jobs['last_job'].isna())].copy()
# Replace 0 years with np.nan
log_individual_jobs['first_year_in_advance'] = log_individual_jobs['first_year_in_advance'].replace([0], np.nan)

list_missing = missing['person_id'].to_list()
for p_id in list_missing:
    log_missing_dems = log_missing_dems.append(get_dems(p_id)) 
    log_missing_jobs = log_missing_jobs.append(get_jobs(p_id)) 
    log_missing_awards = log_missing_awards.append(get_awards(p_id))

for p_id in list_student:
    log_student_dems = log_student_dems.append(get_dems(p_id)) 
    log_student_jobs = log_student_jobs.append(get_jobs(p_id))
    log_student_awards = log_student_awards.append(get_awards(p_id))

for p_id in list_nan: 
    log_nan_dems = log_nan_dems.append(get_dems(p_id)) 
    log_nan_jobs = log_nan_jobs.append(get_jobs(p_id))
    log_nan_awards = log_nan_awards.append(get_awards(p_id))

# %%
log_individual_jobs.to_csv(out_ipynb + 'log_jobs_person.csv', index=False)
log_individual_awards.to_csv(out_ipynb + 'log_jobs_award.csv', index=False)

log_missing_dems.to_csv(out_ipynb + 'log_missing_dems.csv', index=False)
log_missing_jobs.to_csv(out_ipynb + 'log_missing_jobs.csv', index=False)
log_missing_awards.to_csv(out_ipynb + 'log_missing_awards.csv', index=False)

log_student_dems.to_csv(out_ipynb + 'log_student_dems.csv', index=False)
log_student_jobs.to_csv(out_ipynb + 'log_student_jobs.csv', index=False)
log_student_awards.to_csv(out_ipynb + 'log_student_awards.csv', index=False)

log_nan_dems.to_csv(out_ipynb + 'log_nan_dems.csv', index=False)
log_nan_jobs.to_csv(out_ipynb + 'log_nan_jobs.csv', index=False)
log_nan_awards.to_csv(out_ipynb + 'log_nan_awards.csv', index=False)

# %% [markdown]
# ## Log Task Report File

# %%
read()
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# ADVANCE Network Log Task Report
# Generated 03/09/2021 23:04:13 EST by Mara Hubelbank
# ------------------------------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Section 1: Dataset Rundown
# ------------------------------------------------------------------------------------------------------------------------
#
# Our current dataset includes:
# 1360 organizations
# 273 awards
# 1590 individuals
# 2170 individual award roles (with some individuals having multiple roles per grant)
# 2024 individual award roles (after removal of duplicate individuals within the same grant)
# 6687 individual jobs
#
# Between these, there are:
# 195 grant-receiving organizations
# 1590 individuals with at least one award role
# 1.4 award roles per individual, on average
# 7 award role categories
# 112 unique award role titles (before processing)
# 13 job categories
# 2677 unique job titles (before processing)
#
# ------------------------------------------------------------------------------------------------------------------------
#
# Among the individual jobs,
# 1679 are admin_leadership positions (25%)
# 221 are director_managerial positions (3.3%)
# 416 are chair_dept positions (6.2%)
# 308 are director_research positions (4.6%)
# 244 are director_chair positions (3.6%)
# 140 are director_diversity positions (2.1%)
# 2276 are faculty positions (34%)
# 163 are staff_management positions (2.4%)
# 217 are staff_research positions (3.2%)
# 229 are adjunct positions (3.4%)
# 37 are postdoc positions (0.55%)
# 730 are non-uni positions (11%)
# 24 are deceased positions (0.36%)
#
# ------------------------------------------------------------------------------------------------------------------------
#
# Among the individual awards,
# 1079 are grantee roles (53%)
# 121 are day-to-day roles (6%)
# 92 are researcher roles (4.5%)
# 105 are internal evaluator roles (5.2%)
# 455 are external advisor roles (22%)
# 124 are external evaluator roles (6.1%)
# 48 are external consultant roles (2.4%)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Section 2: Missing Data
# ------------------------------------------------------------------------------------------------------------------------
#
# FILE: Individual Jobs (n=6687)
# department column: 6609 rows missing (99%)
# job_end_year column: 1962 rows missing (29%)
# job_start_year_old column: 451 rows missing (6.7%)
# job_start_year column: 445 rows missing (6.7%)
# bio_urls column: 77 rows missing (1.2%)
# job_sequence column: 51 rows missing (0.76%)
# job_title column: 25 rows missing (0.37%)
# employer_name column: 3 rows missing (0.045%)
# job_category column: 3 rows missing (0.045%)
# employer_id column: 1 rows missing (0.015%)
# person_id column: 0 rows missing (0%)
# name column: 0 rows missing (0%)
# person_job_id column: 0 rows missing (0%)
# job_title_full column: 0 rows missing (0%)
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Section 3: Student and NaN Job Categories
# ------------------------------------------------------------------------------------------------------------------------
#
# 0 students dropped for the jobs processing task.
#
#
# The jobs/demographics and individual awards for the individuals with student positions are located in:
# > log_student_jobs.csv, log_student_awards.csv
#
# ------------------------------------------------------------------------------------------------------------------------
#
# 3 no-category positions dropped for the jobs processing task.
# 445 start years were set to 0.
# 1965 end years were set to 3000.
#
# person 1590 has a no-category position in row 2697
# person 1783 has a no-category position in row 3620
# person 2527 has a no-category position in row 6331
#
# The jobs/demographics and individual awards for the individuals with NaN-category positions are located in:
# > log_nan_jobs.csv, log_nan_awards.csv files.
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Section 4: Universities vs. Non-Universities
# ------------------------------------------------------------------------------------------------------------------------
#
# NOTE: The organizations file should be reviewed, since the ASME Board of Governors improperly has a Carnegie ID value,
# so there may be other errors in this data.
#
# 736 organizations are programmatically marked as universities. Of these, 620 are US universities, and 116 are non-US.
# 624 organizations are programmatically marked as non-universities.
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Section 5: Individual Award Date Issues
# ------------------------------------------------------------------------------------------------------------------------
#
# These individuals have at least one job associated with being director of an ADVANCE program which starts before they
# entered the network.
#
# Person 1001 has a job as "director of the university of michigan advance program" which starts in year 1995.
# > Their first award started in 2002 at org 44098792.
# Person 1722 has a job as "director of lehigh's nsf-advance grant" which starts in year 2013.
# > Their first award started in 2015 at org 1213318465.
# Person 2110 has a job as "associate director, advance program" which starts in year 2011.
# > Their first award started in 2012 at org 4012281303.
# Person 2210 has a job as "acting director, advance program" which starts in year 2012.
# > Their first award started in 2018 at org 1397069697.
# Person 2210 has a job as "associate director, advance program, and director of the adv..." which starts in year 2014.
# > Their first award started in 2018 at org 1397069697.
# Person 2210 has a job as "director, advance program" which starts in year 2016.
# > Their first award started in 2018 at org 1397069697.
# Person 2293 has a job as "assistant director of ethnography & evaluation research, cen..." which starts in year 1995.
# > Their first award started in 2002 at org 3311607547.
# Person 2359 has a job as "director, adapp-advance" which starts in year 2008.
# > Their first award started in 2018 at org 1397069697.
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Section 6: Predicting Job Category Misplacement
# ------------------------------------------------------------------------------------------------------------------------
#
# For each category, we output the job titles which contain neither the 15 most frequent terms in their assigned category
#  nor any of the manually defined category keys. This also points to some misspelled job titles, such as "profesor".
#
# Job titles which may not fit in category admin_leadership:
# Person 1018: special advisor to the president
# Person 1021: organizational change management director
# Person 1052: special advisor to the vice-president academic on faculty development
# Person 1053: special advisor to provost for gender
# Person 1121: wellness programs administrator
# Person 1130: prem program director
# Person 1131: deputy director
# Person 1167: advisor to the president
# Person 1198: budget director
# Person 1239: director, the ethos center
# Person 1343: ciesin senior fellow
# Person 1357: director and professor of statistics
# Person 1386: senior advisor
# Person 1386: senior advisor to the president
# Person 1389: special advisor on research development and external partnerships
# Person 1420: school head
# Person 1467: senior advisor for faculty affairs, office of the provost
# Person 1579: special advisor to the provost for women's leadership
# Person 1761: campus executive officer
# Person 1845: medical director, quality
# Person 1872: executive director of the office for economic development and innovations management
# Person 1909: executive coordinator
# Person 1951: faculty liaison, academic and research computing
# Person 1960: ombudsperson
# Person 2066: faculty liaison for tisch college
# Person 2095: advisory board member
# Person 2193: senior advisor to the president
# Person 2244: vp for institutional diversity
# Person 2271: co-chair, bystander intervention committee, stride, advancement of women, equity, and diversity
# Person 2286: executive-in-residence
# Person 2359: senior advisor to the dean for research mentoring at the graduate school
# Person 2419: assistant vice chancellor for academic affairs, and cic campus liaison
# Person 2509: hurlburt chair of mis, school of management
# Person 2519: advisor and founding member, office of continuous improvement and assessment
# Person 2589: university senate chair
# Person 2608: advance program leader
# Person 2609: advance program leader
#
# Job titles which may not fit in category director_managerial:
# Person 1322: chair of the faculty
# Person 1415: asme’s board of governors
# Person 1718: chair of the faculty
# Person 1831: faculty assembly chair, department of computer and electrical engineering and computer science
# Person 1844: founder, uhealth
# Person 2493: vice chair, utpa women faculty network leadership team
#
# Job titles which may not fit in category chair_dept:
#
# Job titles which may not fit in category director_research:
# Person 1532: co-founder brains and lattice
#
# Job titles which may not fit in category director_chair:
#
# Job titles which may not fit in category director_diversity:
#
# Job titles which may not fit in category faculty:
#
# Job titles which may not fit in category staff_management:
# Person 1226: evaluation specialist. center for water and environmental sustainability.
# Person 1226: associate director, institute for natural resources
# Person 1236: administrator
# Person 1301: administrator
# Person 1673: pre-doctoral intern
# Person 1712: clinical psychologist
# Person 1809: facilitator for outcomes assessment
# Person 1907: volunteer
# Person 1975: administrator
# Person 1991: grant writer
# Person 1992: reasearch associate
# Person 2015: counselor
# Person 2040: rector
# Person 2098: associate for special projects
# Person 2194: webmaster
# Person 2205: office of instruction and assessment
# Person 2273: curriculum editor
# Person 2290: intern
# Person 2290: scholarly communication librarian
# Person 2297: administrative secretary
# Person 2452: author
# Person 2473: information technologist
#
# Job titles which may not fit in category staff_research:
# Person 1044: wolfe chair, scientific and technological literacy
#
# Job titles which may not fit in category adjunct:
#
# Job titles which may not fit in category postdoc:
# Person 2585: education coach
#
# Job titles which may not fit in category deceased:
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Section 7: Location of First, Highest, and Last Jobs
# ------------------------------------------------------------------------------------------------------------------------
#
# Found first, highest, and last positions for 96% of the 1590 individuals in our records. (n=1524)
#
# The first jobs of these individuals are:
# 26.8% admin_leadership positions (n=408)
# 3.0% director_managerial positions (n=46)
# 7.2% chair_dept positions (n=109)
# 5.1% director_research positions (n=77)
# 3.3% director_chair positions (n=51)
# 3.0% director_diversity positions (n=46)
# 35.4% faculty positions (n=540)
# 2.8% staff_management positions (n=42)
# 3.4% staff_research positions (n=52)
# 1.5% adjunct positions (n=23)
# 0.3% postdoc positions (n=4)
# 8.1% non-uni positions (n=124)
# 0.1% deceased positions (n=2)
#
# The highest jobs of these individuals are:
# 41.8% admin_leadership positions (n=637)
# 5.8% director_managerial positions (n=88)
# 9.7% chair_dept positions (n=148)
# 6.4% director_research positions (n=97)
# 2.9% director_chair positions (n=44)
# 2.6% director_diversity positions (n=40)
# 21.5% faculty positions (n=328)
# 1.8% staff_management positions (n=27)
# 1.8% staff_research positions (n=27)
# 0.5% adjunct positions (n=8)
# 0.3% postdoc positions (n=4)
# 5.0% non-uni positions (n=76)
# 0.0% deceased positions (n=0)
#
# The last jobs of these individuals are:
# 26.8% admin_leadership positions (n=409)
# 3.3% director_managerial positions (n=51)
# 6.0% chair_dept positions (n=92)
# 4.7% director_research positions (n=72)
# 2.3% director_chair positions (n=35)
# 2.0% director_diversity positions (n=31)
# 32.7% faculty positions (n=498)
# 2.3% staff_management positions (n=35)
# 2.4% staff_research positions (n=37)
# 1.9% adjunct positions (n=29)
# 0.2% postdoc positions (n=3)
# 13.9% non-uni positions (n=212)
# 1.3% deceased positions (n=20)
#
# ------------------------------------------------------------------------------------------------------------------------
#
# 66 individuals are missing first, highest, and last positions.
#
# Of the 66 individuals missing at least one of these positions,
# 100% have zero jobs which are not categorized as student/NaN. (n=66)
# 1.5% have at least one grantee award role. (n=1)
# 82% have at least one day-to-day award role. (n=54)
# 1.5% have at least one researcher award role. (n=1)
# 1.5% have at least one internal evaluator award role. (n=1)
# 6.1% have at least one external advisor award role. (n=4)
# 6.1% have at least one external evaluator award role. (n=4)
# 3% have at least one external consultant award role. (n=2)
#
# The jobs/demographics and individual awards for the individuals missing positions are located in:
# > log_missing_jobs.csv, log_missing_awards.csv
#
# ------------------------------------------------------------------------------------------------------------------------
#
# Found first, highest, and last positions for 97% of the 2024 individual award roles in our records. (n=1957)
#
# The first jobs of these individual award roles are:
# 27.5% admin_leadership positions (n=538)
# 4.0% director_managerial positions (n=79)
# 5.8% chair_dept positions (n=113)
# 4.3% director_research positions (n=85)
# 2.7% director_chair positions (n=52)
# 4.0% director_diversity positions (n=78)
# 34.9% faculty positions (n=683)
# 2.5% staff_management positions (n=48)
# 2.7% staff_research positions (n=52)
# 1.6% adjunct positions (n=32)
# 0.2% postdoc positions (n=3)
# 9.5% non-uni positions (n=186)
# 0.4% deceased positions (n=8)
#
# The highest jobs of these individual award roles are:
# 39.3% admin_leadership positions (n=769)
# 5.9% director_managerial positions (n=116)
# 9.0% chair_dept positions (n=177)
# 5.9% director_research positions (n=116)
# 2.5% director_chair positions (n=48)
# 3.4% director_diversity positions (n=67)
# 23.7% faculty positions (n=464)
# 1.8% staff_management positions (n=36)
# 2.0% staff_research positions (n=40)
# 0.8% adjunct positions (n=15)
# 0.2% postdoc positions (n=4)
# 5.4% non-uni positions (n=105)
# 0.0% deceased positions (n=0)
#
# The last jobs of these individual award roles are:
# 28.0% admin_leadership positions (n=547)
# 3.8% director_managerial positions (n=75)
# 6.8% chair_dept positions (n=134)
# 4.5% director_research positions (n=88)
# 2.3% director_chair positions (n=45)
# 3.5% director_diversity positions (n=68)
# 32.6% faculty positions (n=638)
# 2.5% staff_management positions (n=49)
# 2.6% staff_research positions (n=50)
# 1.7% adjunct positions (n=34)
# 0.2% postdoc positions (n=3)
# 11.0% non-uni positions (n=216)
# 0.5% deceased positions (n=10)
#
# ------------------------------------------------------------------------------------------------------------------------
#
# 67 individual award roles are missing first, highest, and last positions.
#
# Of the 67 individual award roles missing at least one of these positions,
# 100% have zero jobs which are not categorized as student/NaN. (n=67)
# 1.5% have at least one grantee award role. (n=1)
# 81% have at least one day-to-day award role. (n=54)
# 1.5% have at least one researcher award role. (n=1)
# 1.5% have at least one internal evaluator award role. (n=1)
# 6% have at least one external advisor award role. (n=4)
# 6% have at least one external evaluator award role. (n=4)
# 3% have at least one external consultant award role. (n=2)

# %% [markdown]
# # 4.5 Logic Error Detection
#
# The purpose of this final script is to check the log CSVs for potential logic errors. The output will indicate whether the src for first/highest/last jobs need to be debugged and, if so, why.

# %%
def check_highest_logic(log_df, name):
    print('Checking highest job output for the', name, 'file.')
    count = 0
    for _, row in log_df.iterrows():
        if not pd.isna(row['highest_job']):
            if not pd.isna(row['first_job']) and job_comparator(row['highest_job'], row['first_job']) > 0:
                print('The highest job for person', row['person_id'], 'is lower than their first job.')
                count += 1
            if not pd.isna(row['last_job']) and job_comparator(row['highest_job'], row['last_job']) > 0:
                print('The highest job for person', row['person_id'], 'is lower than their last job.')
                count += 1
    if count == 0:
        print('\nFinished: No errors detected.')

# %%
check_highest_logic(log_individual_jobs, 'individual jobs log')
# Out:
# Checking highest job output for the individual jobs log file.
#
# Finished: No errors detected.

# %%
check_highest_logic(log_individual_awards, 'individual awards log')
# Out:
# Checking highest job output for the individual awards log file.
#
# Finished: No errors detected.
